# %%
from google.colab import drive
drive.mount('/drive')
# Out:
# Drive already mounted at /drive; to attempt to forcibly remount, call drive.mount("/drive", force_remount=True).

# %%
import os
import subprocess
repository = "COSC-4368"

base = "/drive/MyDrive/Colab Notebooks"

path = f"{base}/{repository}"

username = "TRD159"

email = "rohan360k@gmail.com"

name = "F4NB0Y3 N1NT3ND0"

token = "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"

owner = username

# %cd {base}

# Check if folder exists
if not os.path.exists(path):
    clone_url = f'https://{username}:{token}@github.com/{owner}/{repository}.git'
    # Clone repository from GitHub
    # !git clone {clone_url}
else:
    print(f"Folder '{path}' already exists.")

# Move to folder
# %cd {path}

# !git pull

# Update .gitconfig using subprocess
subprocess.run(['git', 'config', '--global', 'user.email', email], check=True)
subprocess.run(['git', 'config', '--global', 'user.name', name], check=True)
# Out:
# /drive/MyDrive/Colab Notebooks
# Folder '/drive/MyDrive/Colab Notebooks/COSC-4368' already exists.
# /drive/MyDrive/Colab Notebooks/COSC-4368
# Already up to date.
# CompletedProcess(args=['git', 'config', '--global', 'user.name', 'F4NB0Y3 N1NT3ND0'], returncode=0)

# %%
# !git pull
# Out:
# Already up to date.

# %%
gi

# %%
# !git commit -am "Update Message Here"
# Out:
# On branch main
# Your branch is up to date with 'origin/main'.
#
# Untracked files:
#   (use "git add <file>..." to include in what will be committed)
# 	Untitled0.ipynb
#
# nothing added to commit but untracked files present (use "git add" to track)

# %%
# !git push
# Out:
# Everything up-to-date
